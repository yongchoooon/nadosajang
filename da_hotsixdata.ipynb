# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)

# %%
df8 = pd.read_csv('./8.상주인구.csv', encoding='cp949')
# Out:
# C:\Users\82103\AppData\Local\Temp\ipykernel_5348\417379837.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df8 = pd.read_csv('./8.상주인구.csv', encoding='cp949')

# %%
df1 = pd.read_csv('./1.상권영역(정보).csv', encoding='cp949')

# %%
df1.head(5).T
# Out:
#                    0         1             2             3         4
# 기준_년월_코드      201810    201810        201810        201810    201810
# 상권_구분_코드           A         A             D             D         D
# 상권_구분_코드_명      골목상권      골목상권          발달상권          발달상권      발달상권
# 상권_코드        1000275   1000276       1001045       1001046   1001047
# 상권_코드_명       보문로26길    보문로31길  동작구 총신대입구역_1  서울 관악구 신림역_4   뱅뱅사거리_1
# 엑스좌표_값        201886    201385        198304        193828    202960
# 와이좌표_값        454183    454290        442948        443001    443242
# 시군구_코드         11290     11290         11590         11620     11680
# 행정동_코드      11290600  11290555      11590630      11620695  11680655
# 형태정보             NaN       NaN           NaN           NaN       NaN

# %%
df2 = pd.read_csv('./2.상권변화(자치구).csv', encoding='cp949')

# %%
df2.head(5).T
# Out:
#                     0      1      2      3      4
# 기준_년_코드          2021   2021   2021   2021   2021
# 기준_분기_코드            3      3      3      3      3
# 시군구_코드          11740  11710  11680  11650  11620
# 시군구_코드_명          강동구    송파구    강남구    서초구    관악구
# 상권_변화_지표           LL     LL     LL     HH     LL
# 상권_변화_지표_명       다이나믹   다이나믹   다이나믹     정체   다이나믹
# 운영_영업_개월_평균       111    116    109    127    114
# 폐업_영업_개월_평균        52     55     51     55     53
# 서울_운영_영업_개월_평균    117    117    117    117    117
# 서울_폐업_영업_개월_평균     55     55     55     55     55

# %%
df3 = pd.read_csv('./3.상권변화(행정동).csv', encoding='cp949')

# %%
df3.head(5).T
# Out:
#                        0         1         2         3         4
# 기준_년_코드             2021      2021      2021      2021      2021
# 기준_분기_코드               3         3         3         3         3
# 행정동_코드          11740700  11740690  11740685  11740660  11740650
# 행정동_코드_명            둔촌2동      둔촌1동        길동      성내3동      성내2동
# 상권_변화_지표              HL        HH        LL        HL        LL
# 상권_변화_지표_명          상권축소        정체      다이나믹      상권축소      다이나믹
# 운영_영업_개월_평균          119       170       110       119       116
# 폐업_영업_개월_평균           52        72        49        48        48
# 서울_운영_영업_개월_평균       117       117       117       117       117
# 서울_폐업_영업_개월_평균        55        55        55        55        55

# %%
df5 = pd.read_csv('./5.소득소비(상권배후지).csv', encoding='cp949')

# %%
df5.head(5).T
# Out:
#                        0            1           2           3           4
# 기준 년 코드             2021         2021        2021        2021        2021
# 기준_분기_코드               1            1           1           1           1
# 상권_구분_코드               A            A           A           A           A
# 상권_구분_코드_명          골목상권         골목상권        골목상권        골목상권        골목상권
# 상권_코드            1000193      1000298     1000297     1000296     1000295
# 상권_코드_명           왕산로43길       정릉로27길      정릉로26길      장위로50길       장월로1길
# 월_평균_소득_금액       2729716      3355209     3338064     2416795     2956757
# 소득_구간_코드               6            7           7           5           6
# 지출_총금액        7501923026  11842475922  6179246740  5235197988  4803914725
# 식료품_지출_총금액    2151712515   3099929654  1683952466  1501033989  1364476852
# 의류_신발_지출_총금액   888933146   1428912815   733874296   616414129   574723444
# 생활용품_지출_총금액    553108402    849935987   430168476   374450525   344562961
# ...

# %%
df6 = pd.read_csv('./6.생활인구-1.csv')

# %%
df6.head(3)
# Out:
#    기준 년코드  기준_분기_코드 상권_구분_코드  상권_구분_코드_명    상권_코드   상권_코드.1  상권_코드_명  \
# 0    2021         1        A        골목상권  1000001       계동길   282796
# 1    2021         1        A        골목상권  1000002    난계로27길   320864
# 2    2021         1        A        골목상권  1000003  돈화문로11가길   162400
#
#    총_생활인구_수  남성_생활인구_수  여성_생활인구_수  연령대_10_생활인구_수  연령대_20_생활인구_수  \
# 0    142207     140590      34007          40035          51839
# 1    164461     156403      16361          61774          60579
# 2     90505      71895       9073          32314          32489
#
#    연령대_30_생활인구_수  연령대_40_생활인구_수  연령대_50_생활인구_수  연령대_60_이상_생활인구_수  \
# 0          60856          43971          52088             51175
# 1          51914          52050          78184             74165
# 2          31239          25484          31800             23723
#
#    시간대_1_생활인구_수  시간대_2_생활인구_수  시간대_3_생활인구_수  시간대_4_생활인구_수  시간대_5_생활인구_수  \
# 0         63043         46872         47847         46527         27332
# ...

# %%
df7 = pd.read_csv('./7.직장인구.csv', encoding='cp949')
# Out:
# C:\Users\82103\AppData\Local\Temp\ipykernel_5348\2346517672.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df7 = pd.read_csv('./7.직장인구.csv', encoding='cp949')

# %%
df7.head(10).T
# Out:
#                            0        1        2        3        4        5  \
# 기준_년월_코드                2021     2021     2021     2021     2021     2021
# 기준_분기_코드                   1        1        1        1        1        1
# 상권_구분_코드                   A        A        R        A        A        A
# 상권_구분_코드_명              골목상권     골목상권     전통시장     골목상권     골목상권     골목상권
# 상권_코드                1000007  1000756  1001278  1000058  1000059  1000060
# 상권_코드_명                북촌로5길    사당로8길    남평화시장   백범로90길  서빙고로71길   소월로20길
# 총_직장_인구_수                503      131        5      535      432      151
# 남성_직장_인구_수               419       70        3      288      265       76
# 여성_직장_인구_수                84       61        2      247      167       75
# 연령대_10_직장_인구_수             0        0        0        0        1        0
# 연령대_20_직장_인구_수            31       16        0       62       40       28
# 연령대_30_직장_인구_수           177       19        4      133      104       48
# ...

# %%
df8 = pd.read_csv('./8.상주인구.csv', encoding='cp949')
# Out:
# C:\Users\82103\AppData\Local\Temp\ipykernel_5348\417379837.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df8 = pd.read_csv('./8.상주인구.csv', encoding='cp949')

# %%
df8.head(5).T
# Out:
#                           0        1        2        3        4
# 기준_년_코드                2021     2021     2021     2021     2021
# 기준_분기_코드                  1        1        1        1        1
# 상권_구분_코드                  A        A        A        A        R
# 상권_구분_코드_명             골목상권     골목상권     골목상권     골목상권     전통시장
# 상권 코드               1000002  1000011  1000010  1000012  1001451
# 총 상주인구 수                941      899      946     2571        8
# 남성 상주인구 수               406      484      454     1139        5
# 여성 상주인구 수               535      415      492     1432        3
# 연령대 10 상주인구 수            18       75       94      432        0
# 연령대 20 상주인구 수           437      136      341      288        3
# 연령대 30 상주인구 수           252      102      137      399        1
# 연령대 40 상주인구 수            88      109      106      506        0
# 연령대 50 상주인구 수            69      191      104      412        3
# 연령대 60 이상 상주인구 수         77      286      164      534        1
# ...

# %%
df9 = pd.read_csv('./9.아파트.csv', encoding='cp949')

# %%
df9.head(5).T
# Out:
#                                 0          1          2          3          4
# 기준_년_코드                      2021       2021       2021       2021       2021
# 기준_분기_코드                        4          3          2          1          4
# 상권_구분_코드                        R          R          R          R          R
# 상권_구분_코드_명                   전통시장       전통시장       전통시장       전통시장       전통시장
# 상권_코드                     2130326    2130326    2130326    2130326    2130325
# 상권_코드_명                 고덕 골목형상점가  고덕 골목형상점가  고덕 골목형상점가  고덕 골목형상점가     명일전통시장
# 아파트_단지_수                        1          1          1          1          5
# 아파트_면적_66_제곱미터_미만_세대_수        6.0        6.0        6.0        6.0      203.0
# 아파트_면적_66_제곱미터_세대_수           NaN        NaN        NaN        NaN      372.0
# 아파트_면적_99_제곱미터_세대_수           NaN        NaN        NaN        NaN        NaN
# 아파트_면적_132_제곱미터_세대_수          NaN        NaN        NaN        NaN        NaN
# ...
